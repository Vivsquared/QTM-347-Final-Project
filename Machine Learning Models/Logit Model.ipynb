# %%
import pandas as pd
import numpy as np
import sklearn.model_selection as skm
from ISLP import confusion_table
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler

# %%
#load the dataset
df = pd.read_csv('dataQTM.csv')

#create X and y, drop the empty column
y = df[['diagnosis']]
X = df.drop(['diagnosis', 'id', 'Unnamed: 32'], axis=1).astype('float64')

# %%
#use the 13 predictors that has the best results in best subset selection
X = X[['concave points_worst', 'radius_worst', 'texture_worst', 'area_worst', 'smoothness_se', 'symmetry_worst', 'compactness_se', 'radius_se', 'fractal_dimension_worst', 'compactness_mean', 'concave points_mean', 'concavity_worst', 'concavity_se']]

#split X: trainning size 70% and testing size 30%
X_train, X_test, y_train, y_test = skm.train_test_split(X, y, train_size=0.7, random_state=123)

#add constant
X_train = sm.add_constant(X_train)

#change B to be 0 and M to be 1
y_train['diagnosis'] = y_train['diagnosis'].replace({'B': 0, 'M': 1})

#build a logit model
logit_model = sm.GLM(y_train, X_train, family=sm.families.Binomial())

# %%
# !pip3 install ISLP
from ISLP.models import summarize

#fit the logit model and print a summary
fitted_model = logit_model.fit()
summarize(fitted_model)
# Out:
# Requirement already satisfied: ISLP in /Users/vvy/anaconda3/lib/python3.11/site-packages (0.3.19)
# Requirement already satisfied: numpy<1.25,>=1.7.1 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (1.24.3)
# Requirement already satisfied: scipy>=0.9 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (1.10.1)
# Requirement already satisfied: pandas<=1.9,>=0.20 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (1.5.3)
# Requirement already satisfied: lxml in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (4.9.2)
# Requirement already satisfied: scikit-learn>=1.2 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (1.3.0)
# Requirement already satisfied: joblib in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (1.2.0)
# Requirement already satisfied: statsmodels>=0.13 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (0.14.0)
# Requirement already satisfied: lifelines in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (0.27.8)
# Requirement already satisfied: pygam in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (0.9.0)
# Requirement already satisfied: torch in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (2.0.1)
# Requirement already satisfied: pytorch-lightning in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (2.0.9)
# Requirement already satisfied: torchmetrics in /Users/vvy/anaconda3/lib/python3.11/site-packages (from ISLP) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from pandas<=1.9,>=0.20->ISLP) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from pandas<=1.9,>=0.20->ISLP) (2022.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.2->ISLP) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.13->ISLP) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from statsmodels>=0.13->ISLP) (23.0)
# Requirement already satisfied: matplotlib>=3.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from lifelines->ISLP) (3.7.1)
# Requirement already satisfied: autograd>=1.5 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from lifelines->ISLP) (1.6.2)
# Requirement already satisfied: autograd-gamma>=0.3 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from lifelines->ISLP) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from lifelines->ISLP) (0.6.5)
# Requirement already satisfied: progressbar2<5.0.0,>=4.2.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from pygam->ISLP) (4.2.0)
# Requirement already satisfied: tqdm>=4.57.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from pytorch-lightning->ISLP) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from pytorch-lightning->ISLP) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from pytorch-lightning->ISLP) (2023.4.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from pytorch-lightning->ISLP) (4.7.1)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from pytorch-lightning->ISLP) (0.9.0)
# Requirement already satisfied: filelock in /Users/vvy/anaconda3/lib/python3.11/site-packages (from torch->ISLP) (3.9.0)
# Requirement already satisfied: sympy in /Users/vvy/anaconda3/lib/python3.11/site-packages (from torch->ISLP) (1.11.1)
# Requirement already satisfied: networkx in /Users/vvy/anaconda3/lib/python3.11/site-packages (from torch->ISLP) (3.1)
# Requirement already satisfied: jinja2 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from torch->ISLP) (3.1.2)
# Requirement already satisfied: future>=0.15.2 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from autograd>=1.5->lifelines->ISLP) (0.18.3)
# Requirement already satisfied: astor>=0.8 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from formulaic>=0.2.2->lifelines->ISLP) (0.8.1)
# Requirement already satisfied: interface-meta>=1.2.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from formulaic>=0.2.2->lifelines->ISLP) (1.3.0)
# Requirement already satisfied: wrapt>=1.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from formulaic>=0.2.2->lifelines->ISLP) (1.14.1)
# Requirement already satisfied: requests in /Users/vvy/anaconda3/lib/python3.11/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines->ISLP) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines->ISLP) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines->ISLP) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines->ISLP) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines->ISLP) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.0->lifelines->ISLP) (3.0.9)
# Requirement already satisfied: six in /Users/vvy/anaconda3/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels>=0.13->ISLP) (1.16.0)
# Requirement already satisfied: python-utils>=3.0.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from progressbar2<5.0.0,>=4.2.0->pygam->ISLP) (3.8.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from jinja2->torch->ISLP) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from sympy->torch->ISLP) (1.3.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vvy/anaconda3/lib/python3.11/site-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning->ISLP) (2023.7.22)
#                              coef  std err      z  P>|z|
# const                    -38.0917   17.468 -2.181  0.029
# concave points_worst      58.7847   37.554  1.565  0.117
# radius_worst              -1.6923    1.935 -0.875  0.382
# texture_worst              0.4415    0.131  3.380  0.001
# area_worst                 0.0335    0.021  1.606  0.108
# smoothness_se            634.8520  253.060  2.509  0.012
# symmetry_worst            20.2219   12.461  1.623  0.105
# compactness_se          -223.8461  104.148 -2.149  0.032
# radius_se                 17.3635    5.269  3.295  0.001
# fractal_dimension_worst   32.3892   95.511  0.339  0.735
# compactness_mean         -13.2500   40.189 -0.330  0.742
# concave points_mean       49.1750   69.084  0.712  0.477
# concavity_worst           22.0929   11.515  1.919  0.055
# concavity_se             -37.9194   48.163 -0.787  0.431

# %%
#add constant to X_test
X_test = sm.add_constant(X_test)

#change B to be 0 and M to be 1
y_test['diagnosis'] = y_test['diagnosis'].replace({'B': 0, 'M': 1})

# %%
#predict y values with the fitted logit model
y_pred = fitted_model.predict(X_test)

#if the predictted value is greater than 0.5, then assign it to 1
y_pred_class = (y_pred > 0.5).astype(int)

#sum up the numbers of misclassified values
misclassified_logit = (y_pred_class != y_test['diagnosis']).sum()
total = len(y_test)

#calculate the misclassification rate
logit_misclassification_rate = misclassified_logit / total
logit_misclassification_rate
# Out:
# 0.017543859649122806

# %%
#change 0 back to B and 1 back to M for the confusion table
y_pred_class= y_pred_class.replace({0:'B', 1:'M'})
y_test= y_test.replace({0:'B', 1:'M'})

# %%
#create a confusion table
confusion_table(y_pred_class, y_test_logit.diagnosis)
# Out:
# Truth        B   M
# Predicted
# B          102   2
# M            1  66
